# %%
#!pip install --upgrade --no-cache-dir git+https://github.com/rongardF/tvdatafeed.git
#!pip install python-dotenv

# %%
import os
from dotenv import load_dotenv
from tvDatafeed import TvDatafeedLive, Interval
load_dotenv()

username = os.environ.get("TRADINGVIEW_USERNAME")
password = os.environ.get("TRADINGVIEW_PASSWORD")
tv = TvDatafeedLive(username, password)
prices = tv.get_hist(symbol='XAUUSD',exchange='ICMARKETS',interval=Interval.in_1_hour,n_bars=500)

# %%
prices
# Out:
#                                symbol     open     high      low    close  \
# datetime
# 2024-09-18 05:00:00  ICMARKETS:XAUUSD  2572.36  2574.19  2570.06  2573.78
# 2024-09-18 06:00:00  ICMARKETS:XAUUSD  2573.77  2576.47  2572.84  2575.95
# 2024-09-18 07:00:00  ICMARKETS:XAUUSD  2575.94  2576.48  2568.01  2568.70
# 2024-09-18 08:00:00  ICMARKETS:XAUUSD  2568.69  2569.25  2565.78  2567.75
# 2024-09-18 09:00:00  ICMARKETS:XAUUSD  2567.74  2570.06  2566.70  2569.29
# ...                               ...      ...      ...      ...      ...
# 2024-10-17 17:00:00  ICMARKETS:XAUUSD  2688.89  2696.47  2684.77  2695.69
# 2024-10-17 18:00:00  ICMARKETS:XAUUSD  2695.70  2696.76  2687.62  2693.37
# 2024-10-17 19:00:00  ICMARKETS:XAUUSD  2693.33  2693.43  2683.96  2692.26
# 2024-10-17 20:00:00  ICMARKETS:XAUUSD  2692.31  2694.26  2690.51  2692.02
# 2024-10-17 21:00:00  ICMARKETS:XAUUSD  2692.03  2692.21  2691.59  2691.74
#
#                       volume
# datetime
# 2024-09-18 05:00:00   8911.0
# 2024-09-18 06:00:00   7641.0
# 2024-09-18 07:00:00   6389.0
# 2024-09-18 08:00:00   9992.0
# 2024-09-18 09:00:00  10972.0
# ...                      ...
# 2024-10-17 17:00:00  22349.0
# 2024-10-17 18:00:00  18657.0
# 2024-10-17 19:00:00  14704.0
# 2024-10-17 20:00:00   9796.0
# 2024-10-17 21:00:00     70.0
#
# [500 rows x 6 columns]
